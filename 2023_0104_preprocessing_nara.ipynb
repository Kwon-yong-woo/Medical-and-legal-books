# %%
import pandas as pd
import os
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display
import re
from tqdm.auto import tqdm

import matplotlib.pyplot as plt

# %%
def new_sample(sample):
    try:
        if sample[-2:] == '. ':
            new_sample = sample

        elif sample[-1] == '.':
            new_sample = sample+' '

        elif sample[-1] != '.':
            new_sample = sample+'. '

        else:
            print('please check the data!')
    except:
        new_sample = sample
        
    return new_sample

# %%
def split_sent(text:str)->list:
    # split 시 무시할 패턴 정의  
    # 숫자. 로 끝나는 경우 
    check = """(eqs?\.)|(figs?\.)|(sect\.)|\     # eq.(eqs.), fig.(figs.), sec.(SEC.),
    (sec\.)|(et\.)|(\s?al\.)|(\s?et\.?\sal\.)|\  #  et. al. 
    (S?\.?\s?\d*ff\.)$|(dvbl\.)|(vgl\.)|\        # 추가: '.857ff.','3) Vgl.'  11.18
    ^(e\.)|(\s?\(?[A-Z]{1,4}\.)|^([A-Z]\.)|\     # 시작 시 e. g. (S. S. 로 시작할 경우, ABCD. 와 같은 경우 추가(+11.18)
    ([가-힣]{1,2}\s\.)$|\                         # 다. 일경우만 제외하는 등 변경 필요
    (\(?e\.\s?g\.)|(\(?i\.\s?e\.)|\
    ([MDCLXVI]{1,2}\.)$\                         # 로마자 추가
    |(dix.)\
    |(no\.)|([0-9]\.)$|(vs\.)|(ref\.)|(cf\.)\    # no. 1. vs. ref.(Ref.) cf.(Cf.)
    """
    pp = re.compile(check, re.VERBOSE|re.IGNORECASE)
    na_count = 0

        
    # 예외처리: 문장 끝에 .(공백없음)으로 끝나거나 .이 없는 경우
    sample = new_sample(text)
    splited_list = []
    prev_end = 0
    
    try:
        # .으로 끝나는 모든 경우를 find
        for sent in re.finditer('(\.\s)', sample):
            start = sent.span()[0]
            end = sent.span()[1]

            if start < 6:
                token = sample[start-start:end-1]
            else:
                token = sample[start-6:end-1]

    #         print()
    #         print(pp.search(token))
    #         print(token)
    #         print(prev_end, end)
    #         print(len(sample))

            # '. ' 앞뒤에 check에 해당하는 패턴이 없는 경우 문장으로 나누기
            if (pp.search(token) == None):
                if re.search('(\s\(?\w\.\)?)$', token) == None:  # 위의 check에서 제대로 동작 안 해서 따로 집어 넣음
                    splited_list.append(sample[prev_end:end-1])
                    prev_end = end

            elif pp.search(token) != None:
                if len(sample) == end:
                    splited_list.append(sample[prev_end:end-1])
                    
    except:
        print(f'error occured!')
        print(sample)
    return splited_list

# %%
test_ = "LB0298_헌법소송법_nara"

# %%
reg = re.compile(r"(\w+)_")

# %%
reg.findall(test_)
# Out:
# ['LB0298_헌법소송법']

# %%
path_1 = r"C:\Users\Samsung\jupyter\Project_Medical_Legal\data\20230104\nara\00 변환"
reg = re.compile(r"(\w+)_")

os.chdir(path_1)
tq = tqdm(os.listdir())
fn_list = []
for i in tq:
    if i.endswith(".txt"):
        fn_ = reg.findall(i.replace(".","_"))[0]
        fn_list.append(fn_)
        print(fn_)
        
        f = open(path_1+"\\"+i, 'rt',encoding="iso-8859-1")
        globals ()["{}".format(fn_)] = ""
        line = f.read()
        try:
            line = bytes(line,"iso-8859-1").decode("utf-8")
        except:
            try:
                line = bytes(line,"iso-8859-1").decode("utf-16")
            except:
                try:
                    line = bytes(line,"iso-8859-1").decode("euc-kr")
                except:
                    line = bytes(line,"iso-8859-1").decode("cp949")
        globals ()["{}".format(fn_)] = globals ()["{}".format(fn_)] + line
         #print(line)
        f.close()
# Out:
#   0%|          | 0/281 [00:00<?, ?it/s]
# LB0033_교회분쟁관계법_nara
# LB0035_기술이전계약론_nara
# LB0052
# LB0055_신미국특허법_nara
# LB0057
# LB0062
# LB0064
# LB0074_국제사법_nara
# LB0079_계약법_nara
# LB0082
# LB0085
# LB0086
# LB0088
# LB0099
# LB0114
# LB0118_민사소송실무_nara
# LB0121_지적소송실무_nara
# LB0134_법학입문_nara
# LB0171
# LB0173
# LB0212
# LB0217
# LB0233
# LB0246
# LB0251
# LB0260
# LB0272
# LB0293
# LB0298_헌법소송법_nara
# LB0307
# LB0327_배임죄판례백선_nara
# LB0328_배임죄에대한몇가지오해_nara
# LB0342
# LB0349
# LP0020
# LP0026
# LP0122
# LP0153
# LP0154
# LP0161_부동산금융법_nara
# LP0204
# LP0212
# LP0241
# LP0243
# LP0246
# LP0253
# LP0273
# LP0277_법률가의글쓰기
# LP0298_학논문작성법
# LP0324_생활법률_nara
# LP0333
# LP0366
# LP0389
# LP0390
# LP0391
# LP0420
# LP0421_금융법강의01
# LP0433
# LP0434
# LP0477
# LP0483_자본시장법상기업공시
# LP0497
# LP0498
# LP0529
# LP0533
# LP0537
# LP0542
# LP0569
# LP0717_지적재산권법_nara
# LP0721_특허법3
# LP0723
# LP0751_민사판례연구31권_nara
# LP0755_민사판례연구34_nara
# LP0758_민사판례연구_nara
# LP0759_민사판례연구38권_nara
# LP0760_민사판례연구39권_nara
# LP0762_민사판례연구40권_nara
# LP0763_민사판례연구제41권_nara
# LP0764_민사판례연구제42권_nara
# LP0765
# LP0784_행정판례연구11_nara
# LP0785_행정판례연구12_nara
# LP0786_행정판례연구13_nara
# LP0787
# LP0788
# LP0789
# LP0792
# LP0793
# LP0795
# LP0806
# LP0807
# LP0808
# LP0810
# LP0884
# LP0885_신판례행정법입문_nara
# LP0887
# LP0899
# LP0904
# LP0919_행정판례평선_nara
# LP0929_국가권력규범론_nara
# LP0932_기본권총론종_nara
# LP0933_대한민국헌법사전_nara
# LP0942_신헌법입문_nara
# LP0955
# LP0956
# LP0958
# LP0976_헌법재판론_nara
# LP1002_경영판단원칙과형법
# LP1018_예술형법
# LP1021
# LP1026
# LP1040
# LP1069
# LP1075
# LP1081_공공계약법의기초이론
# LP1086
# LP1088_금융규제법개론_nara
# LP1089
# LP1090
# LP1101
# LP1105
# LP1107
# LP1113
# LP1114_부동산공시법_nara
# LP1120
# LP1122
# LP1124
# LP1126
# LP1134
# LP1135
# LP1136
# LP1139
# LP1141
# LP1142_이론
# LP1151
# MK0221
# MK0223_의학통계ABC_nara
# MK0240

# %%
save_path = r"C:\Users\Samsung\jupyter\Project_Medical_Legal\data\20230104\nara\result"

# %%
def find_chapter(origi_,reg):
    spli_ = []
    for i in reg.finditer(origi_):
        spli_.append([i.group(),i.span()])
    return spli_

# %%
def split_chapter(origi_):
    reg = re.compile("\[\[CHAPTER\]\] +(\w+) +\[\[BODY\]\] +(\w+)-?(\w+)?")
    spli_ = find_chapter(origi_,reg)
    if spli_ != []:
        pass
    elif spli_ == []:
        reg = re.compile("CHAPTER")
        spli_ = find_chapter(origi_,reg)
    if spli_ != []:
        data_all = []
        for i in range(len(spli_)):
            chap = spli_[i][0]
            try:
                star_ = spli_[i][1][1]
                end_ = spli_[i+1][1][0]
                data_ = origi_[star_:end_].split("  ")
            except:
                star_ = spli_[i][1][1]
                data_ = origi_[star_:].split("  ")
            data_all.append([chap,data_])
    else:
        data_all = []
        for i in origi_.split("  "):
            chap = ""
            data_all.append([chap,[i]])
    return data_all

# %%
tq = tqdm(fn_list)
for fn_ in tq:
    test_ = globals ()["{}".format(fn_)]
    fn_s = test_.splitlines()
    origi_ = [i.strip() for i in fn_s ]
    # rule 1 = 2칸이상을 2칸으로
    origi_ = re.sub(' {2,}','  ', " ".join(origi_))
    
    # chapter 별로 나누기
    #
    
    data_all = split_chapter(origi_)
        
    # dataframne 만들기
    df_data = []

    for data_ in data_all:
        num_ = 0
        chap_ = data_[0]
        paras_ = data_[1]
        for para_ in paras_:
            sen_ = split_sent(para_)
            df_data.append([chap_,num_,sen_])
            num_ += 1
    df_ = pd.DataFrame(df_data).rename(columns={0:"Chapter",1:"paragraph",2:"sentences"})
    df_.to_excel(save_path + "\\" + fn_ + ".xlsx")
# Out:
#   0%|          | 0/281 [00:00<?, ?it/s]

# %%
test_ = LB0033_교회분쟁관계법_nara

# %%
   
fn_s = test_.splitlines()
origi_ = [i.strip() for i in fn_s ]
# rule 1 = 2칸이상을 2칸으로
origi_ = re.sub(' {2,}','  ', " ".join(origi_))

# %%
origi_.split("  ")
# Out:
# ["제1장 교회일반론 제1절 서론 통계청의 발표자료에 의하면, 2005. 11. 1. 현재 우리나라 인구 47,041,000명 중 가톨릭교 교인은 5,146,000명으로 10.9%이고, 개신교 교인은 8,616,000명으로서 18.3%이며, 2015년 기준 개신교 인구는 9,676,000명으로 19.7%에 이르렀다고 한다. 우리나라에 기독교가 선교된 지 가톨릭교회로서는 230여년, 개신교로서는 130여년이라는 서구 기독교역사에 비교하면 매우 짧은 기간임에도 불구하고 위와 같이 기독교는 오늘날 신구교를 합하여 신도수 1,400만에 이르는 대종교로 성장하였다. 기독교는 초기에는 민족의 개화와 교육에 앞장서 수많은 인재와 민족지도자를 양성하였고, 의료선교․구제봉사 등 많은 사회활동을 통하여 국가사회에 기여해 왔으며, 일제의 침략과 통치하에서는 민족의 해방과 독립, 의식개혁에 앞장섰고, 해방 후에는 근대화와 민주화에 크게 기여하였다. 그러나 짧은 선교역사 속에서 급속한 성장을 하다 보니 여러 가지 문제점들이 드러나고 있다. 그 중에 특히 개신교4)에 있어서 가장 심각한 문제점으로 지적되는 것 중의 하나가 교회 내에서 일어나는 교인과 교인, 교회와 교회, 교회와 교인, 교회와 교단, 교단과 교단 사이에 빈번하게 일어나는 분쟁의 문제이다. 교회분쟁은 광의로는 교회와 국가 간의 관계에서 발생하는 분쟁을 포함하지만 협의로는 교회 내에서 발생하는 분쟁만을 의미하고, 본서에서는 후자의 의미로 사용한다. 따라서 민사상 분쟁이 아닌 교회와 국가와의 관계에서 발생하는 분쟁인 종교의 자유와 관련된 문제, 교회의 세금문제, 인허가문제, 형사상의 문제 등은 특별한 경우 외에는 논의의 범위에서 제외한다. 이러한 교회분쟁은 교회가 분열되지 않은 경우에도 많이 나타나지만, 교회가 분열되는 과정 및 분열의 결과로 인하여 더욱 심화되고, 결과적으로는 교회운영권, 교회재산권과 직간접으로 연결되어 있다. 분쟁이 순수한 교리나 신앙상의 문제로 발생하는 경우라고 해도 진행되는 추이에 따라서는 교회운영권 및 재산권에 관한 분쟁으로 비화하는 경우가 많고, 순수한 운영권 및 재산권에 관한 분쟁이 종교분쟁의 외형으로 나타나기도 한다. 무엇보다 개신교 최대의 교파라고 할 수 있는 장로교회의 분열상은 교회가 분열할 수 있는 극한상황을 보여주고 있다. 그럼에도 불구하고 우리나라에서는 교회분열을 인정할 것인지 부정할 것인지, 그리고 각 경우 재산권 및 교회운영권은 어떻게 할 것인지에 대한 법률의 규정이 없음은 물론 그 밖의 교회분쟁 시에도 이러한 점을 규율하는 실체법상, 절차법상 규정이 없고, 그에 관한 법이론도 정립되어 있지 않다. 다만 교회분열 시의 재산권의 귀속 문제 등에 관하여 여러 판결을 통하여 어느 정도 일관된 이론을 전개하여 왔고, 대법원 1993. 1. 19. 선고 91다1226 전원합의체 판결(이하, ‘93년 전원합의체 판결’이라고 한다)을 통해서 교회의 분열의 의미 및 재산귀속에 대한 법원의 입장을 더욱 분명히 하였다. 그러나 실제로 교회분쟁 사건에 있어서 위 대법원 판례의 입장만으로는 해결할 수 없는 사례가 속출하여 그 실효성이 문제되어 왔다. 그러던 중 대법원은 2006. 4. 20. 선고 2004다37775 전원합의체 판결(이하 ‘2006년 대법원 전원합의체 판결’이라고 한다)을 통하여 종래 논의되어 온 교회의 분열에 따른 재산귀속에 관한 견해를 바꾸어 상당히 명확한 견해를 밝힘으로써 그 해결점을 제시하고 있다. 그렇지만 위 판결로도 교회분열과 관련된 모든 문제에 대하여 명확하고 합리적인 해결책을 제시하였다고 볼 수 없으며, 구체적인 사건의 해결에 있어서 위 판결을 그대로 적용하기 어려운 경우도 많이 나타나고 있다. 또한 교회분열까지는 가지 않더라도 수시로 많은 교회분쟁이 나타나고 있고, 이를 해결하는 방법도 쉽지 않은 것이 현실이다. 그리고 정교분리의 원칙상 순수한 종교상의 문제에 관하여는 국가가 사법권의 개입을 자제하고 자율적 해결을 도모하는 것이 바람직한데, 자율적 해결의 가능성이 없어 부득이 법적분쟁으로 발전하는 경우에는 사법권이 개입하여야 하겠지만 이 경우에도 일반단체와 동일하게 취급하면 그것이 바람직하지 못하거나 분쟁해결에 도움이 되지 못하는 경우가 나타난다. 이에 관하여 대법원은 그동안 권징재판에 대한 사법권의 개입에 대하여는 비교적 개입을 자제하여 왔지만 그 기준이 명확하다고 볼 수 없고, 특히 다른 교회분쟁에 대하여는 더욱 그러하다. 교회의 분쟁과 그로 인한 재산귀속분쟁에 관한 일련의 판례가 형성되어 있는 나라는 우리나라를 제외하고는 미국이 거의 유일하다. 역사적으로 미국은 식민지시대 이래 수많은 교회분열과 그에 따른 교회재산분쟁 및 소송을 경험하여 왔으며 그 때문에 미국법상 교회재산분쟁법(law of church property disputes)이라고 할 만한 법분야가 판례이론을 중심으로 형성되어 있다. 한편, 한국개신교와 그 교단들의 대부분이 미국교회에서 파송한 미국인 선교사들에 의하여 설립되었고, 종교 내지 교회와 국가의 관계에 있어서 미국과 우리나라는 모두 국교불인정․정교분리원칙 등 종교다원주의를 채택하고 있는 점에서 동일하기 때문에 교회분열의 모습과 그에 따른 재산분쟁의 양상도 매우 유사하다. 따라서 교회분쟁을 연구함에는 미국의 판례이론을 정확히 이해하는 것이 필요하다. 그리고 일본은 비록 교회분쟁에 관한 판례는 형성되어 있지 않으나 다른 종교단체에 대한 판례가 상당히 형성되어 있으므로 이를 각 참고하기로 한다. 그리하여 본서에서는 교인과 교인, 교회와 교회, 교회와 교인, 교회와 교단, 교단과 교단 사이에 일어나는 전반적인 법률문제를 살펴보고 그 해결방법 및 기준을 마련함으로써 교회 분쟁의 예방 및 해결책을 제시하고자 한다. 제2절 교회의 의의 교회가 무엇이며 그 본질과 속성이 어떤 것이냐에 관하여는 역사적으로 다양한 견해가 있어 왔으며 가톨릭교회와 개신교 사이에 견해의 일치를 보지 못하고 있음은 물론, 같은 개신교 내에서도 교회의 개념에 대하여 신학적으로는 다양한 의미로 사용되고 있다. 예컨대 교회당, 즉 교회의 건물의 의미로 사용되기도 하며, 신자들의 특별한 조직체를 의미하는 용어로도 사용되고 있으며, 교파를 언급하기 위해 사용되기도 한다. Ⅰ. 성경에 나타난 교회 구약에서 교회라는 단어의 원래 뜻은 두 가지의 개념으로 쓰인다. 즉 ‘카할’과 ‘에다’이다. 전자는 집회(assembly) 즉, 어떤 목적을 위하여 사람들이 함께 모이는 행위를 의미하고, 후자는 회중(congregation) 즉, 제의나 법을 중심으로 모인 이스라엘의 공동체, 특히 종교적인 측면에서 하나님의 백성으로서의 공동체를 뜻한다. 교회로 번역되는 헬라어 원어는 ‘에클레시아’(εκκλησια)로서 이 말의 어원적 의미는 ‘밖으로 부르다’[εκ(out)＋ﾄκαλεω(call)] 즉 ‘불러내다’(to call out)라는 뜻이다. 이 어휘를 신약성경에서 처음 사용하신 분은 예수그리스도이시다. “주는 그리스도시요 살아 계신 하나님의 아들이시니이다.”라고 신앙고백을 한 사도 베드로에게, “너는 베드로라 내가 이 반석 위에 내 교회(ecclesia)를 세우리니 음부의 권세가 이기지 못하리라”고 말씀하신 것이다. 그 후에도 같은 어휘를 사용하신 적은 있으나 그 의미를 친히 정의하신 바는 없다. 물론 그리스도의 제자들인 사도들에 의하여 교회에 관한 가르침이 신약성경 서신서들에 자세히 기록되어 있다. 신약성경에서 ‘에클레시아’는 ① 가장 흔히 일정한 지역에 있는 기독교인들의 개개의 단체를 가리키는 지교회, ② 어떤 개인의 가정에 모인 가정교회, ③ 외면적으로 그리스도를 향한 신앙을 고백하고 임명된 직원(officer)들의 지도 아래 예배할 목적으로 조직된 지상의 모든 단체를 의미하는 개념의 유형적 보편교회, ④ 가장 포괄적인 의미에서 천상에서나 지상에서나 그리스도와 영적으로 연합된 혹은 장차 연합될 모든 신자들을 구성원으로 하는 하나의 보편교회를 의미하는 무형적 보편교회 등 다양한 의미로 사용된다. 그리고 어떤 경우에는 훨씬 더 광범위한 지역이 언급되기도 하고, 과거와 미래의 모든 신자들을 포함하고 있기도 한다. 이러한 포괄성의 관점에서 교회를 신학적으로 정의하면 ‘그리스도의 ...
#  '에 둔다. 제3조 (목적) 본 교회는 예수 그리스도의 몸된 교회로서, 감리회의 신앙과 전통을 보존하고 교회의 질서를 유지하며 교회가 부흥하고 성장함을 목적으로 한다. 제4조 (사업) 본 교회는 목적달성을 위하여 아래와 같은 사업을 행한다. 1. 전도․교육․구호를 위한 사업 2. 사회교회 및 봉사에 관한 사업 3. 어린이 유아원 ․유치원 사업 4. 기타 필요한 부대사업 제5조 (시행세칙) 본 정관에 규정하지 아니한 내용은 시행세칙으로 정한다. 제2장 회원 제1절 교인 제6조 (교인의 정의) 교인은 예수 그리스도를 구주로 믿고, 감리회 회원이 되기를 결심하여 본 교회에 등록하여 신앙생활을 하는 자를 의미한다. 제7조 (교인의 구분) 본 교회 교인은 다음과 같이 구분된다. 1. 원입인: 주를 믿기로 결심하여 본 교회에 출석하는 자 2. 세례아동: 부모의 신앙고백으로 유아세례를 받은 12세 이하의 아동 3. 세례인: 세례아동으로 13세 이상 된 자 또는 원입인으로 1년 이상 교회에 충실히 출석하여 세례를 받은 자 4. 입교인: 18세 이상 세례인 중 담임자가 예문대로 입교시킨 자. 다만 타 교회로부터 이명된 자는 등록함으로써 입교한 것으로 본다. 제8조 (교인자격의 취득과 상실) ① 본 교회의 교인자격은 교인명부에 등록됨으로써 취득한다. ② 정관에서 정하는 바에 따라 당회에서 교인 제명 결의를 하거나 권징 재판에 의하여 출교 판결을 하는 경우 상급기관의 재판과 관계없이 그때부터 교인의 지위가 상실된다. ③ 교인 제명 또는 출교된 자가 다시 본 교회의 교인이 되
의 행정사무를 수행하기 위하여 사무국을 두고, 필요한 직원을 채용한다. ② 사무국의 조직, 운영에 관한 상세한 내용은 시행세칙으로 정한다. 제3장 의회 제1절 당회 제28조 (당회) 본 교회에 등록된 모든 입교인으로 구성되는 의회를 당회라 한다. 제29조 (당회의 구성원) ① 당회는 본 교회에 교인으로 등록된 입교인과 연회와 지방회에서 파송한 교역자로 구성한다. ② 의장은 담임자가 되며 서기는 당회에서 선출한다. ③ 담임자 유고시에는 감리사가 의장이 되고, 감리사 유고시에는 부담임자, 서리담임자, 장로 중 선임연장자 순으로 당회 의장이 된다. 다만 부담임자, 서리 ...
#  '에 위치한다. 제4조 (목적) 본 교회는 하나님을 영화롭게 하며 영원토록 그를 즐거워하기 위하여 하나님께 예배드리고, 성도 간에 서로 교제하며, 그의 아들 예수 그리스도의 인격과 삶을 본받아 하나님의 교회와 세상을 섬기고, 땅끝까지 복음을 전하는 것을 그 목적으로 한다. 제5조 (연혁) 본 교회는 ○○○○년에 제3조의 위치에서 설립하여 현재까지 전도와 선교, 구제, 봉사 등 하나님의 뜻에 합당한 선한 사업을 하여 왔다. 제6조 (신조) 신․구약 성경 66권은 하나님의 말씀으로 신앙과 본분에 대하여 정확무오한 유일의 법칙이며, 웨스트민스터 신도게요와 성경 대․소요리문답을 성경에 근거한 것으로 인정한다. 제7조 (사업) 1. 전도, 교육, 구제, 선교, 교제를 위한 사업 2. 사회복지사업 3. 기타 교회의 목적을 위한 사업 제2장 교인 제8조 (교인의 정의) 교인이란 예수그리스도를 자신의 “주와 구주”로 영접하고, 소정의 절차에 따라 입회하여, 교회의 공동예배에 참석하는 자이다. 제9조 (교인의 구분과 지위의 취득) ① 원입교인은 예수를 믿기로 작정하고 교회에 교인으로 등록한 후 공예배에 참석하는 교인이다. ② 학습교인은 원입교인으로 교회에 출석한지 6개월이 경과되고 만 14세 이상이 된 교인으로서 신앙에 대한 학습문답과 서약을 한 교인이다. ③ 세례교인은 만 14세 이상의 학습교인으로 학습 받은 후 6개월 이상 근실히 교회에 출석하고 세례문답을 한 후 세례를 받은 교인이다. ④ 입교인은 유아세례를 받은 자가 만14세 이상이 되고 입교문답을 거친 후 입교식을 행한 교인이다. ⑤ 이명 또는 전입교인은 다른 교회에서 세례를 받은 자로서 소정의 교육과 절차를 거쳐 당회의 결의를 거친 교인이다. ⑥ 위 각 교인은 교인명부에 등록하여야 교인의 지위를 취득한다. ⑦ 당회는 연초 교인총회 전에 교인명부를 작성하여 교회사무실에 비치하여야 한다. 제10조 (교인의 지위의 정지와 상실) ① 본 교회의 교인은 다음의 경우에 당회결의로 교인의 지위가 정지된다. 1. 정당한 사유 없이 6개월 이상 본 교회 예배에 계속하여 참석하지 아니한 때 2. 정당한 사유 없이 교인의 의무를 상당기간 계속하여 이행하지 아니한 때 3. 제명․ 출교 이외의 책벌을 받아 근신중인 때 ② 본 교회의 교인은 다음의 경우에 당회결의로 교인의 지위가 상실된다. 1. 교인이 탈퇴의사를 표시한 때 2. 제명․출교의 책벌을 받은 때 3. 교계에서 이단으로 규정한 단체에 가입하거나 활동을 한 사실이 확인된 때 4. 교인 지위가 정지된 이후 정당한 사유 없이 1년 이상 본 교회 예배에 계속 참석하지 아니한 때 ③ 교인의 지위의 정지와 상실 사유가 소멸한 때에는 해당 교인의 요청 또는 직권으로 당회결의에 의하여 교인의 지위를 회복할 수 있다. 제11조 (교인의 권리) ① 교인은 공예배에 참여할 권리가 있다. ② 교인은 정관 또는 당회의 결의에 따라 교회재산의 사용․수익권, 재판을 받을 권리, 청원할 권리가 있다. ③ 제8조의 세례교인, 입교인, 이명․전입교인은 성찬 참례권, 교인총회 회원권 및 정관에 따른 선거권과 피선거권이 있다. 제12조 (교인의 의무) ① 교인은 교회가 정한 예배 및 기도회와 집회에 참여할 의무가 있다. ② 교인은 전도, 봉사, 구제의 의무가 있다. ③ 교인은 온전한 십일조와 기타 헌금의 의무가 있다. ④ 교인은 정관 등 교회의 규약을 준수하고 치리에 복종할 의무가 있다. 제3장 교회의 직원 제1절 통칙 제13조 (직원의 정의) 교회의 직원이란 예수 그리스도께서 교회에 맡긴 (청지기)직분을 수행하는 사역자를 의미하며, 교회의 행정직원과 구분된다. 제14조 (직원의 구분) ① 교회의 직원은 교역자와 임직자로 구분하되 시무정년까지 직분을 담당하는 항존(恒存)직과 일정 기간 동안 직분을 담당하는 임시직이 있다. ② 항존직은 담임목사, 장로, 집사, 권사이다. ③ 항존직의 시무정년은 만 70세로 한다. ④ 임시직은 부목사, 전도사, 서리집사이다. 제2절 교역자 제15조 (목사) ① 목사는 담임목사, 부목사, 원로목사, 은퇴목사, 협동목사가 있다. ② 담임(위임)목사는 본 교회를 대표하며, 공동의회, 당회, 제직회의 회장이 되며, 하나님의 말씀으로 성도를 교훈하고, 성례를 행하며, 교인을 축복한다. 제16조 (목사의 자격) ① 본 교회의 목사는 디모데전서 3:1~7절에서 정한 바와 같이 신앙이 진실하고 행위가 복음에 적합하며, 가정을 잘 다스리고 타인의 존경을 받는 자로서 국가의 인가를 받은 신학대학원을 졸업한 후 목사안수를 받은 자이어야 한다. ② 본 교회의 담임목사는 위 목사안수를 받고 3년 이상 교역 경험을 가진 자이어야 한다. 제17조 (담임목사의 청빙과 임직) ① 담임목사를 청빙하고자 하는 경우에는 당회원 3분의 2 이상의 출석과 출석 당회원 3분의 2이상의 결의로 당회가 추천한다. ② 당회가 추천한 후보자에 대하여 교인총회 회원 3분의 1이상 출석과 출석 회원 3분의 2이상의 찬성으로 청빙을 결의한다. ③ 청빙결의가 있은 때에는 세례교인 과반수의 서명을 받은 후에 담임목사로 임직한다. ④ 본 교회에서 사임(사직) 또는 은퇴하는 담임목사의 배우자 및 직계비속과 그 직계비속의 배우자와 교회 시무장로의 배우자 및 직계비속과 그 직계비속의 배우자는 담임목사로 청빙할 수 없다. ⑤ 담임목사의 청빙을 위해 청빙위원회의 구성 등 구체적인 절차를 시행세칙으로 정할 수 있다. 제18조 (담임목사의 사임 및 해임) ① 목사가 부득이한 사유로 인하여 시무사임을 원할 때는 당회에 사임서를 제출하고 당회의 결의를 거쳐 사임할 수 있다. ② 목사가 교회에서 불미스러운 행위를 한 사실이 확인될 때에는 당회 및 교인총회의 결의에 의하여 교회는 시무사임을 권고할 수 있다. ③ 목사가 일반 형사범죄(행정범 및 과실범은 죄에)를 저지르고 집행유예 이상의 형을 받거나 도덕적으로 치명적인 범과가 있는 경우, 교리가 이단에 해당하는 경우에는 당회원 3분의 2 이상의 찬성과 세레교인 3분의 1이상의 출석과 출석 세례교인 3분의 2 이상의 찬성을 얻은 교인 총회의 결의로 해임할 수 있다. 제19조 (원로목사와 은퇴목사) ① 본 교회에서 20년 이상 시무한 목사는 은퇴 후 그 명예를 보존하기 위해 원로목사로 추대할 수 있다. ② 원로목사 추대는 당회의 결의와 교인총회의 결의에 의한다. 원로목사와 은퇴목사는 은퇴 후 본 교회의 치리, 교훈, 행정 등에 일체의 영향력을 행사해서는 안 된다. ③ 원로목사와 은퇴목사의 예우는 시행세칙으로 정한다. 제20조 (부목사와 전도사 등) ① 담임목사는 당회의 결의를 거쳐 부목사와 전도사 등 교역자를 둘 수 있다. ② 부목사와 전도사는 담임목사를 보좌하여 설교, 교육, 심방, 성례식 등의 활동을 한다. ③ 부목사와 전도사의 임기는 1년으로 하되, 당회의 결의로 연임할 수 있다. 제3절 임직자 제21조 (장로의 선출과 직무) ① 장로는 디모데전서 3:1~7절에 합한 자로, 10년이상 무흠 세례교인으로서 40세 이상 된 자 중에서 선임한다. ② 장로는 당회의 추천을 받아 교인총회에서 선출한다. ③ 장로는 피택된 이후 6개월 이상 당회의 지도아래 교육을 받고, 담임목사의 안수를 받아야 한다. ④ 장로는 목사와 협력하여 교회의 신령적 관계를 살피며, 당회원이 된다. ⑤ 장로후보의 추천과 선출에 관한 구체적인 절차는 시행세칙으로 정할 수 있다. 제22조 (집사․권사의 선출과 직무) ① 집사․권사 후보는 디모데전서 3:8~10절에 합한 자로, 5년 이상 무흠 세례교인으로서 집사는 35세 이상의 남자, 권사는 40세 이상의 여자 중에서 선임한다. ② 집사․권사는 당회의 추천을 받아 교인총회에서 선출한다. 다만 집사는 안수를 받아야 한다. ③ 집사․권사는 목사와 장로와 협력하여 교회에 봉사하고 헌금을 수납하며 구제에 관한 일을 담당하며, 제직회원이 된다. 제23조 (서리집사) 무흠 세례교인으로서 본 교회에 2년 이상 출석한 교인 중에서 25세 이상인 자를 당회의 결의에 의하여 1년 단위로 매년 초에 서리집사로 임명한다. 제4장 기관 제1절 총칙 제24조 (기관의 지위) ① 교인총회는 의결권있는 교인들의 최고의결기관이다. ② 당회는 교회운영을 지도 감독하는 기관이며 신령상 모든 사무를 처 ...
