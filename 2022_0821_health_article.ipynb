# %%
import pandas as pd
import csv
import os
import string
from datetime import datetime
import pickle
import re
#from tqdm import tqdm
import gzip
from tqdm.notebook import tqdm

# %%
path_ = r"C:\Users\Samsung\jupyter\Project_Medical_Legal"
os.chdir(path_)

# %%
data = pd.read_csv("./health_news_inputdata.tsv",sep='\t')

# %%
data.head()
# Out:
#    Unnamed: 0  index                                         Sentence_1  \
# 0           0      0  앵커： 요즘 우리 평균수명은 많이 늘었지만 몸이 불편해 고생하시는 노인들 주변에 많...
# 1           1      1          그냥 오래 사는 게 아니라 건강하게 오래 사는 이른바 건강수명이 중요하죠.
# 2           2      2                             우리의 현 실태를 가 집중 취재했습니다.
# 3           3      3  한국인의 평균수명은 현재  5세 OECD 국가의 평균치인 79세를 거의 따라 잡았습니다.
# 4           4      4  그러나 사고나 질병으로 거동이 불편한 기간을 뺀 건강히 사는 기간 즉 건강수명은 그...
#
#                                           Sentence_2
# 0          그냥 오래 사는 게 아니라 건강하게 오래 사는 이른바 건강수명이 중요하죠.
# 1                             우리의 현 실태를 가 집중 취재했습니다.
# 2  한국인의 평균수명은 현재  5세 OECD 국가의 평균치인 79세를 거의 따라 잡았습니다.
# 3  그러나 사고나 질병으로 거동이 불편한 기간을 뺀 건강히 사는 기간 즉 건강수명은 그...
# 4  최근 조사에 따르면 건강수명은  6세 즉 말년에 10년 가량은 병상에 있다가 삶을 ...

# %%
# 기사 number 역추적하기 
seg_list =list(data[data["Sentence_1"]==data["Sentence_2"]].index)
len(seg_list)
# Out:
# 342

# %%
# maop / apply
def func_len(x):
    return len(x)

# %%
from tqdm.notebook import tqdm
import time 
tqdm.pandas()
strat_time = time.time()
data["Sen1_len"] = data["Sentence_1"].map(lambda x: func_len(x))
end_time = time.time()

# %%
print(end_time-strat_time)
# Out:
# 3.8364012241363525

# %%
tq = tqdm(range(len(data)))
len_list = []
for i in tq:
    len_list.append(len(data["Sentence_1"][i]))
# Out:
#   0%|          | 0/8554096 [00:00<?, ?it/s]

# %%
def func_len_2(x):
    x_1 = len(x["Sentence_1"])
    x_2 = len(x["Sentence_2"])
    return x_1 + x_2

# %%
data["Sen1_len2"] = data.apply(lambda x: func_len_2(x),axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-e8818e0ef519> in <module>
# ----> 1 data["Sen1_len2"] = data.apply(lambda x: func_len_2(x),axis=1)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
# ...

# %%
data.loc[0:100]["Sentence_1"][0]
# Out:
# '앵커： 요즘 우리 평균수명은 많이 늘었지만 몸이 불편해 고생하시는 노인들 주변에 많이 봅니다.'

# %%
data.loc[0:100].loc[0]
# Out:
# Unnamed: 0                                                    0
# index                                                         0
# Sentence_1    앵커： 요즘 우리 평균수명은 많이 늘었지만 몸이 불편해 고생하시는 노인들 주변에 많...
# Sentence_2            그냥 오래 사는 게 아니라 건강하게 오래 사는 이른바 건강수명이 중요하죠.
# Sen1_len                                                     52
# Name: 0, dtype: object

# %%
def find_func(x):
    global find_buff
    if x["Sentence_1"] == find_buff:
        find_buff = x["Sentence_2"]
        x_2 = ""
        return x_2
    else:
        x_2 = x["index"]
        find_buff = x["Sentence_2"]
        return x_2

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
find_buff = data["Sentence_1"][0]
#tqdm.pandas()
seg_list_2 = list(data.apply(lambda x: find_func(x),axis=1))

# %%
seg_list_3 = [x for x in seg_list_2 if x != ""]

# %%
len(seg_list_3)
# Out:
# 8553707

# %%
len(seg_list_2)
# Out:
# 8554096

# %%
seg_list_2
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  42,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  59,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  70,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  81,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  107,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  118,
#  '',
#  '',
#  '',
#  '',
#  123,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
list_test = []
for i in range(data):
    appemd(ata[])

# %%
data.loc[170:180]
# Out:
#      Unnamed: 0  index                                         Sentence_1  \
# 170         170    170        어혈은 기혈의 흐름을 막아 통증을 유발하고 신체의 다른 부위에도 해를 끼친다.
# 171         171    171  〈이재동경희대 한의학과 교수〉- 대한민국 희망언론 경향신문 구독신청의 디지털뉴스이용...
# 172         172    172                                                 〉.
# 173         173    173  평균수명이 훨씬 더 높은데도 불구하고 노년기 삶의 질은 여성이 남성에 비해 떨어진다...
# 174         174    174  분당서울대병원 노인보건연구단 신경정신과 이석범 교수팀은 2005년 8월부터 2006...
# 175         175    175  이 교수팀은 이번에 전반적 건강상태와 삶의 질에 대한 노인들의 주관적 판단을 ‘신체...
# 176         176    176  그 결과 조사대상 여성들은 거의 모든 면에서 남성들보다 낮은 수준을 보였으며 그 이...
# 177         177    177  실제로 노인여성은 노인남성에 비해 치매에 빠질 위험성이  8배나 높고 우울증과 무릎...
# 178         178    178  이밖에 생활습관병성인병의 최대 위험인자로 꼽히는 대사증후군과 비만 위험성도  1배 ...
# 179         179    179  이 교수는 남성과는 달리 여성은 폐경 후 에스트로겐 등 여성 호르몬 분비의 현저한 ...
# 180         180    180  다이어트를 한번이라도 경험한 여성이라면 아무리 노력해도 잘 빠지지 않는 부위가 있다...
#
#                                             Sentence_2
# ...

# %%
data["Sentence_1"][177]
# Out:
# '실제로 노인여성은 노인남성에 비해 치매에 빠질 위험성이  8배나 높고 우울증과 무릎 관절염 발병 위험성은 각각  2배와  6배 높은 것으로 측정됐다.'

# %%
seg_list_3
# Out:
# [42,
#  59,
#  70,
#  81,
#  107,
#  118,
#  123,
#  144,
#  168,
#  173,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  284,
#  285,
#  286,
#  287,
#  288,
# ...

# %%
seg_list_2
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  42,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  59,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  70,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  81,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  107,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  118,
#  '',
#  '',
#  '',
#  '',
#  123,
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
type(seg_list_3[0])
# Out:
# float

# %%
# progress bar
from tqdm import tqdm, tqdm_notebook
tqdm.pandas(tqdm_notebook)

# %%
find_buff
# Out:
# '김상일 병원장은 4월중 선별진료소에 엑스레이X-ray 검사부스를 추가 설치하여 현장에서 바로 검사와 판독을 할 수 있는 시스템을 마련할 예정이다.'

# %%
# Out:
# 342

# %%
data.loc[39:45]
# Out:
#     Unnamed: 0  index                                         Sentence_1  \
# 39          39     39  3년 안에 서너 살 올려야 한다는 얘기인데요 2000년 66세에서 2005년에  6...
# 40          40     40  개인의 행복도 행복이지만 요즘 같은 저출산 고령화 사회에서 은퇴시점을 늦추고 노동인...
# 41          41     41                                      앵커：  잘 들었습니다.
# 42          42     42  2007년 세계 인구‘는 지난해보다 7560만명이 늘어난 66억1590만명으로 집계됐다.
# 43          43     43     우리나라 평균수명은 남성이  4세로 세계 30위 여성이  8세로 18위를 기록했다.
# 44          44     44                     영유아 사망률은 세계에서 가장 낮은 수준으로 나타났다.
# 45          45     45  인구보건복지협회와 유엔인구기금UNFPA이 27일 발간한 ‘2007 세계인구 현황보고...
#
#                                            Sentence_2  segment segment_0
# 39  개인의 행복도 행복이지만 요즘 같은 저출산 고령화 사회에서 은퇴시점을 늦추고 노동인...        0
# 40                                      앵커：  잘 들었습니다.        0
# 41                                      앵커：  잘 들었습니다.        0
# 42     우리나라 평균수명은 남성이  4세로 세계 30위 여성이  8세로 18위를 기록했다.        1         1
# ...

# %%
seg_list_2 = []
for i in range(0,1000):
    if data["Sentence_2"][i] !=  data["Sentence_1"][i+1] :
        seg_list_2.append(i)

# %%
seg_list_2
# Out:
# [41,
#  58,
#  69,
#  80,
#  106,
#  117,
#  122,
#  143,
#  167,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  284,
#  285,
#  286,
#  287,
# ...

# %%
seg_list
# Out:
# [41,
#  58,
#  69,
#  80,
#  106,
#  117,
#  122,
#  143,
#  167,
#  172,
#  174,
#  175,
#  176,
#  177,
#  178,
#  179,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  6747,
#  6748,
#  6749,
#  8531,
#  16887,
#  20162,
#  22682,
#  22685,
#  23548,
#  23550,
#  23552,
#  23554,
#  27093,
#  31381,
#  31384,
#  31387,
#  31390,
#  32283,
#  32300,
#  34066,
# ...

# %%
data.loc[170:176]
# Out:
#      Unnamed: 0  index                                         Sentence_1  \
# 170         170    170        어혈은 기혈의 흐름을 막아 통증을 유발하고 신체의 다른 부위에도 해를 끼친다.
# 171         171    171  〈이재동경희대 한의학과 교수〉- 대한민국 희망언론 경향신문 구독신청의 디지털뉴스이용...
# 172         172    172                                                 〉.
# 173         173    173  평균수명이 훨씬 더 높은데도 불구하고 노년기 삶의 질은 여성이 남성에 비해 떨어진다...
# 174         174    174  분당서울대병원 노인보건연구단 신경정신과 이석범 교수팀은 2005년 8월부터 2006...
# 175         175    175  이 교수팀은 이번에 전반적 건강상태와 삶의 질에 대한 노인들의 주관적 판단을 ‘신체...
# 176         176    176  그 결과 조사대상 여성들은 거의 모든 면에서 남성들보다 낮은 수준을 보였으며 그 이...
#
#                                             Sentence_2  segment segment_0
# 170  〈이재동경희대 한의학과 교수〉- 대한민국 희망언론 경향신문 구독신청의 디지털뉴스이용...        9
# 171                                                 〉.        9
# 172                                                 〉.        9
# 173                                                 〉.       10        10
# ...

# %%
set(seg_list_2) - set(seg_list)
# Out:
# {173,
#  180,
#  197,
#  221,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  284,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  337,
#  338,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  378,
#  379,
#  380,
#  381,
#  382,
#  383,
#  384,
#  385,
#  386,
#  387,
#  388,
# ...

# %%
len(seg_list_2)
# Out:
# 837

# %%
data[data["Sentence_1"][]]

# %%
seg_dic = {}
seg_dic[0] = 0
for i in range(len(seg_list)):
    seg_dic[seg_list[i]+1] = i+1

# %%
seg_dic
# Out:
# {0: 0,
#  42: 1,
#  59: 2,
#  70: 3,
#  81: 4,
#  107: 5,
#  118: 6,
#  123: 7,
#  144: 8,
#  168: 9,
#  173: 10,
#  175: 11,
#  176: 12,
#  177: 13,
#  178: 14,
#  179: 15,
#  180: 16,
#  182: 17,
#  183: 18,
#  184: 19,
#  185: 20,
#  186: 21,
#  187: 22,
#  188: 23,
#  189: 24,
#  190: 25,
#  191: 26,
#  192: 27,
#  193: 28,
#  194: 29,
#  195: 30,
#  196: 31,
#  197: 32,
#  199: 33,
#  200: 34,
#  201: 35,
#  202: 36,
#  203: 37,
#  204: 38,
#  205: 39,
#  206: 40,
#  207: 41,
#  208: 42,
#  209: 43,
#  210: 44,
#  211: 45,
#  212: 46,
#  213: 47,
#  214: 48,
#  215: 49,
#  216: 50,
#  217: 51,
#  218: 52,
#  219: 53,
#  220: 54,
#  221: 55,
#  223: 56,
#  224: 57,
#  225: 58,
#  226: 59,
#  227: 60,
#  228: 61,
#  229: 62,
#  230: 63,
#  231: 64,
#  232: 65,
#  233: 66,
#  234: 67,
#  235: 68,
#  236: 69,
#  237: 70,
#  238: 71,
#  239: 72,
#  240: 73,
#  241: 74,
#  242: 75,
#  243: 76,
#  244: 77,
#  245: 78,
#  246: 79,
#  247: 80,
#  248: 81,
#  249: 82,
#  250: 83,
# ...

# %%
def numbering_func(x):
    try:
        x_2 = int(seg_dic[x])
    except:
        x_2 = ""
    return x_2

# %%
tqdm.pandas()
data["segment_0"]= data["index"].map(lambda x: numbering_func(x))

# %%
data.head()
# Out:
#    Unnamed: 0  index                                         Sentence_1  \
# 0           0      0  앵커： 요즘 우리 평균수명은 많이 늘었지만 몸이 불편해 고생하시는 노인들 주변에 많...
# 1           1      1          그냥 오래 사는 게 아니라 건강하게 오래 사는 이른바 건강수명이 중요하죠.
# 2           2      2                             우리의 현 실태를 가 집중 취재했습니다.
# 3           3      3  한국인의 평균수명은 현재  5세 OECD 국가의 평균치인 79세를 거의 따라 잡았습니다.
# 4           4      4  그러나 사고나 질병으로 거동이 불편한 기간을 뺀 건강히 사는 기간 즉 건강수명은 그...
#
#                                           Sentence_2  segment segment_0
# 0          그냥 오래 사는 게 아니라 건강하게 오래 사는 이른바 건강수명이 중요하죠.        0         0
# 1                             우리의 현 실태를 가 집중 취재했습니다.        0
# 2  한국인의 평균수명은 현재  5세 OECD 국가의 평균치인 79세를 거의 따라 잡았습니다.        0
# 3  그러나 사고나 질병으로 거동이 불편한 기간을 뺀 건강히 사는 기간 즉 건강수명은 그...        0
# 4  최근 조사에 따르면 건강수명은  6세 즉 말년에 10년 가량은 병상에 있다가 삶을 ...        0

# %%
def numbering_func_2(x):
    global seg_buff
    if x == "":
        x_2 = seg_buff
    else:
        x_2 = x
        
        seg_buff = x
    return x_2

# %%
tqdm.pandas()
seg_buff = 0
data["segment"] = data["segment_0"].map(lambda x: numbering_func_2(x))

# %%
data_test = data[["index","segment","Sentence_1"]].set_index("index").rename(columns={"Sentence_1":"sentence"})
data_test
# Out:
#          segment                                           sentence
# index
# 0              0  앵커： 요즘 우리 평균수명은 많이 늘었지만 몸이 불편해 고생하시는 노인들 주변에 많...
# 1              0          그냥 오래 사는 게 아니라 건강하게 오래 사는 이른바 건강수명이 중요하죠.
# 2              0                             우리의 현 실태를 가 집중 취재했습니다.
# 3              0  한국인의 평균수명은 현재  5세 OECD 국가의 평균치인 79세를 거의 따라 잡았습니다.
# 4              0  그러나 사고나 질병으로 거동이 불편한 기간을 뺀 건강히 사는 기간 즉 건강수명은 그...
# ...          ...                                                ...
# 8554091      342  이밖에 실내공기오염의 지표인 이산화탄소CO2의 경우 교실은 최대값 2980평균 18...
# 8554092      342  그러나 학교보건법은 미세먼지와 이산화탄소환기량조·습도 등에 대해서만 규제하고 있을 ...
# 8554093      342  유기홍 의원은 신축 학교가 계속 늘어나는 현실에서 학교내 실내 대기 문제의 심각성에...
# 8554094      342   면서 환경부의 권고기준치를 더욱 세밀하게 만들고 이를 학교에 동일하게 적용시켜야 한다.
# 8554095      342                                            고 주장했다.
#
# [8554096 rows x 2 columns]

# %% [markdown]
# # 기존 for 구문 VS lambda

# %%
input_data = pd.DataFrame()

sent_1 = []
sent_2 = []

article_num = int(528365)

for i in tqdm(range(article_num)):
    sentences = all_article[all_article.segment == i] #기사별로 문장을 구분

    sent_1.extend(list(sentences.sentence.values)) #현재문장
    sent_2.extend(list(sentences[1:].sentence.values)) #다음문장
    sent_2.append(sent_2[-1]) #마지막 문장 복사

# %%
import time

# %%
strat_time = time.time()

# %%
input_data = pd.DataFrame()

sent_1 = []
sent_2 = []

article_num = int(528365)

for i in tqdm(range(article_num)):
    sentences = all_article[all_article.segment == i] #기사별로 문장을 구분

    sent_1.extend(list(sentences.sentence.values)) #현재문장
    sent_2.extend(list(sentences[1:].sentence.values)) #다음문장
    sent_2.append(sent_2[-1]) #마지막 문장 복사
